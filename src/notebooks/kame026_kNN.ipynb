# %%
import seaborn as sns

df = sns.load_dataset("iris")
X = df.loc[:, df.columns != "species"]
y = df["species"]

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)
# Out:
# /Users/dav_id3/Development/analysis-environment/.venv/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3, random_state=0)

# %%
import pandas as pd

result_df = pd.concat([X, pd.DataFrame(kmeans.labels_, columns=["kmeans_result"])],axis=1)
sns.pairplot(result_df, hue="kmeans_result")

# %%
sns.pairplot(df, hue="species")
