# %%
import pymc as pm
import numpy as np
import pandas as pd
import arviz as az
import matplotlib.pyplot as plt

# %%
# データセットの設定
n_schools = 5  # 学校の数
n_teachers_per_school = 3  # 各学校における教師の数
n_classes_per_teacher = 2  # 各教師におけるクラスの数
n_students_per_class = 30  # 各クラスにおける学生の数

# ランダムデータ生成
np.random.seed(0)

# 学校、教師、クラスの効果をランダムに生成
school_effects = np.random.normal(0, 5, n_schools)
teacher_effects = np.random.normal(0, 3, n_schools * n_teachers_per_school)
class_effects = np.random.normal(0, 2, n_schools * n_teachers_per_school * n_classes_per_teacher)

# データフレームの生成
data = []
for school_id in range(n_schools):
    for teacher_id in range(n_teachers_per_school):
        for class_id in range(n_classes_per_teacher):
            for student_id in range(n_students_per_class):
                # 学校、教師、クラスの効果を組み合わせて学生の成績を計算
                score = (
                    50 + school_effects[school_id] +
                    teacher_effects[school_id * n_teachers_per_school + teacher_id] +
                    class_effects[school_id * n_teachers_per_school * n_classes_per_teacher + 
                                  teacher_id * n_classes_per_teacher + class_id] +
                    np.random.normal(0, 10)
                )
                data.append({
                    "StudentID": f"S_{school_id}_{teacher_id}_{class_id}_{student_id}",
                    "Score": max(0, min(100, score)),  # 成績を0〜100の範囲に制限
                    "ClassID": f"C_{school_id}_{teacher_id}_{class_id}",
                    "TeacherID": f"T_{school_id}_{teacher_id}",
                    "SchoolID": f"School_{school_id}"
                })

df = pd.DataFrame(data)
print(df.head())
print(df.info())
for _, r in df.iterrows():
    print(r)
# Out:
#    StudentID      Score  ClassID TeacherID  SchoolID
# 0  S_0_0_0_0  41.827783  C_0_0_0     T_0_0  School_0
# 1  S_0_0_0_1  54.651473  C_0_0_0     T_0_0  School_0
# 2  S_0_0_0_2  45.674397  C_0_0_0     T_0_0  School_0
# 3  S_0_0_0_3  38.976127  C_0_0_0     T_0_0  School_0
# 4  S_0_0_0_4  50.500626  C_0_0_0     T_0_0  School_0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  900 non-null    object
#  1   Score      900 non-null    float64
#  2   ClassID    900 non-null    object
#  3   TeacherID  900 non-null    object
#  4   SchoolID   900 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 35.3+ KB
# None
# StudentID    S_0_0_0_0
# Score        41.827783
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 0, dtype: object
# StudentID    S_0_0_0_1
# Score        54.651473
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 1, dtype: object
# StudentID    S_0_0_0_2
# Score        45.674397
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 2, dtype: object
# StudentID    S_0_0_0_3
# Score        38.976127
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 3, dtype: object
# StudentID    S_0_0_0_4
# Score        50.500626
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 4, dtype: object
# StudentID    S_0_0_0_5
# Score        55.065767
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 5, dtype: object
# StudentID    S_0_0_0_6
# Score        51.447621
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 6, dtype: object
# StudentID    S_0_0_0_7
# Score        53.807167
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 7, dtype: object
# StudentID    S_0_0_0_8
# Score        44.439228
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 8, dtype: object
# StudentID    S_0_0_0_9
# Score        47.155037
# ClassID        C_0_0_0
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 9, dtype: object
# StudentID    S_0_0_0_10
# Score         44.057844
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 10, dtype: object
# StudentID    S_0_0_0_11
# Score         47.186917
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 11, dtype: object
# StudentID    S_0_0_0_12
# Score         42.650986
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 12, dtype: object
# StudentID    S_0_0_0_13
# Score         33.519622
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 13, dtype: object
# StudentID    S_0_0_0_14
# Score          52.55671
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 14, dtype: object
# StudentID    S_0_0_0_15
# Score         46.764639
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 15, dtype: object
# StudentID    S_0_0_0_16
# Score         34.480465
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 16, dtype: object
# StudentID    S_0_0_0_17
# Score         55.410271
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 17, dtype: object
# StudentID    S_0_0_0_18
# Score         41.709465
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 18, dtype: object
# StudentID    S_0_0_0_19
# Score         51.301902
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 19, dtype: object
# StudentID    S_0_0_0_20
# Score         58.073354
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 20, dtype: object
# StudentID    S_0_0_0_21
# Score         52.072278
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 21, dtype: object
# StudentID    S_0_0_0_22
# Score         62.176455
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 22, dtype: object
# StudentID    S_0_0_0_23
# Score          38.43419
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 23, dtype: object
# StudentID    S_0_0_0_24
# Score         54.805865
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 24, dtype: object
# StudentID    S_0_0_0_25
# Score         43.934348
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 25, dtype: object
# StudentID    S_0_0_0_26
# Score         42.074477
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 26, dtype: object
# StudentID    S_0_0_0_27
# Score         44.993952
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 27, dtype: object
# StudentID    S_0_0_0_28
# Score         47.666923
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 28, dtype: object
# StudentID    S_0_0_0_29
# Score         51.344102
# ClassID         C_0_0_0
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 29, dtype: object
# StudentID    S_0_0_1_0
# Score        45.544167
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 30, dtype: object
# StudentID    S_0_0_1_1
# Score         66.20393
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 31, dtype: object
# StudentID    S_0_0_1_2
# Score         61.85229
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 32, dtype: object
# StudentID    S_0_0_1_3
# Score        41.833228
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 33, dtype: object
# StudentID    S_0_0_1_4
# Score        72.078187
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 34, dtype: object
# StudentID    S_0_0_1_5
# Score        76.154557
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 35, dtype: object
# StudentID    S_0_0_1_6
# Score        68.983461
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 36, dtype: object
# StudentID    S_0_0_1_7
# Score        55.396417
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 37, dtype: object
# StudentID    S_0_0_1_8
# Score        46.488139
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 38, dtype: object
# StudentID    S_0_0_1_9
# Score        67.740183
# ClassID        C_0_0_1
# TeacherID        T_0_0
# SchoolID      School_0
# Name: 39, dtype: object
# StudentID    S_0_0_1_10
# Score         53.163896
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 40, dtype: object
# StudentID    S_0_0_1_11
# Score         69.420116
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 41, dtype: object
# StudentID    S_0_0_1_12
# Score         59.278415
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 42, dtype: object
# StudentID    S_0_0_1_13
# Score         66.962056
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 43, dtype: object
# StudentID    S_0_0_1_14
# Score         60.759329
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 44, dtype: object
# StudentID    S_0_0_1_15
# Score         64.261397
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 45, dtype: object
# StudentID    S_0_0_1_16
# Score         57.300665
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 46, dtype: object
# StudentID    S_0_0_1_17
# Score          75.05437
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 47, dtype: object
# StudentID    S_0_0_1_18
# Score         58.464786
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 48, dtype: object
# StudentID    S_0_0_1_19
# Score         61.215559
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 49, dtype: object
# StudentID    S_0_0_1_20
# Score         76.027172
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 50, dtype: object
# StudentID    S_0_0_1_21
# Score         43.718075
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 51, dtype: object
# StudentID    S_0_0_1_22
# Score         44.490815
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 52, dtype: object
# StudentID    S_0_0_1_23
# Score         66.889632
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 53, dtype: object
# StudentID    S_0_0_1_24
# Score         45.464431
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 54, dtype: object
# StudentID    S_0_0_1_25
# Score         76.631877
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 55, dtype: object
# StudentID    S_0_0_1_26
# Score         53.059475
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 56, dtype: object
# StudentID    S_0_0_1_27
# Score         49.721117
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 57, dtype: object
# StudentID    S_0_0_1_28
# Score         76.425086
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 58, dtype: object
# StudentID    S_0_0_1_29
# Score         72.000813
# ClassID         C_0_0_1
# TeacherID         T_0_0
# SchoolID       School_0
# Name: 59, dtype: object
# StudentID    S_0_1_0_0
# Score        82.074989
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 60, dtype: object
# StudentID    S_0_1_0_1
# Score        72.459846
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 61, dtype: object
# StudentID    S_0_1_0_2
# Score        54.787143
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 62, dtype: object
# StudentID    S_0_1_0_3
# Score        82.500049
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 63, dtype: object
# StudentID    S_0_1_0_4
# Score        60.719366
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 64, dtype: object
# StudentID    S_0_1_0_5
# Score        71.423963
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 65, dtype: object
# StudentID    S_0_1_0_6
# Score        72.871919
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 66, dtype: object
# StudentID    S_0_1_0_7
# Score        61.849298
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 67, dtype: object
# StudentID    S_0_1_0_8
# Score        69.540193
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 68, dtype: object
# StudentID    S_0_1_0_9
# Score        72.621466
# ClassID        C_0_1_0
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 69, dtype: object
# StudentID    S_0_1_0_10
# Score         67.163655
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 70, dtype: object
# StudentID    S_0_1_0_11
# Score         52.405391
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 71, dtype: object
# StudentID    S_0_1_0_12
# Score         66.381781
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 72, dtype: object
# StudentID    S_0_1_0_13
# Score         76.663258
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 73, dtype: object
# StudentID    S_0_1_0_14
# Score         56.453721
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 74, dtype: object
# StudentID    S_0_1_0_15
# Score         61.903054
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 75, dtype: object
# StudentID    S_0_1_0_16
# Score         59.047864
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 76, dtype: object
# StudentID    S_0_1_0_17
# Score         81.892037
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 77, dtype: object
# StudentID    S_0_1_0_18
# Score         70.122347
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 78, dtype: object
# StudentID    S_0_1_0_19
# Score         67.474018
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 79, dtype: object
# StudentID    S_0_1_0_20
# Score         55.700239
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 80, dtype: object
# StudentID    S_0_1_0_21
# Score         68.791891
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 81, dtype: object
# StudentID    S_0_1_0_22
# Score         56.656073
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 82, dtype: object
# StudentID    S_0_1_0_23
# Score         63.717705
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 83, dtype: object
# StudentID    S_0_1_0_24
# Score         57.040939
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 84, dtype: object
# StudentID    S_0_1_0_25
# Score         70.163732
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 85, dtype: object
# StudentID    S_0_1_0_26
# Score         69.165308
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 86, dtype: object
# StudentID    S_0_1_0_27
# Score         61.316412
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 87, dtype: object
# StudentID    S_0_1_0_28
# Score         67.359467
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 88, dtype: object
# StudentID    S_0_1_0_29
# Score         52.468784
# ClassID         C_0_1_0
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 89, dtype: object
# StudentID    S_0_1_1_0
# Score        45.273621
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 90, dtype: object
# StudentID    S_0_1_1_1
# Score        64.580114
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 91, dtype: object
# StudentID    S_0_1_1_2
# Score        61.852932
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 92, dtype: object
# StudentID    S_0_1_1_3
# Score        66.536511
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 93, dtype: object
# StudentID    S_0_1_1_4
# Score        84.017645
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 94, dtype: object
# StudentID    S_0_1_1_5
# Score        69.630992
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 95, dtype: object
# StudentID    S_0_1_1_6
# Score        51.057975
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 96, dtype: object
# StudentID    S_0_1_1_7
# Score         71.35636
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 97, dtype: object
# StudentID    S_0_1_1_8
# Score        47.027123
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 98, dtype: object
# StudentID    S_0_1_1_9
# Score        55.570351
# ClassID        C_0_1_1
# TeacherID        T_0_1
# SchoolID      School_0
# Name: 99, dtype: object
# StudentID    S_0_1_1_10
# Score         59.503781
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 100, dtype: object
# StudentID    S_0_1_1_11
# Score         77.319624
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 101, dtype: object
# StudentID    S_0_1_1_12
# Score         52.738649
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 102, dtype: object
# StudentID    S_0_1_1_13
# Score         51.921812
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 103, dtype: object
# StudentID    S_0_1_1_14
# Score         59.201672
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 104, dtype: object
# StudentID    S_0_1_1_15
# Score         53.551414
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 105, dtype: object
# StudentID    S_0_1_1_16
# Score         71.452556
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 106, dtype: object
# StudentID    S_0_1_1_17
# Score         49.386882
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 107, dtype: object
# StudentID    S_0_1_1_18
# Score          48.71151
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 108, dtype: object
# StudentID    S_0_1_1_19
# Score         55.807996
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 109, dtype: object
# StudentID    S_0_1_1_20
# Score         55.205872
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 110, dtype: object
# StudentID    S_0_1_1_21
# Score         79.481517
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 111, dtype: object
# StudentID    S_0_1_1_22
# Score         69.680405
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 112, dtype: object
# StudentID    S_0_1_1_23
# Score         61.061709
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 113, dtype: object
# StudentID    S_0_1_1_24
# Score         47.931842
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 114, dtype: object
# StudentID    S_0_1_1_25
# Score         68.629827
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 115, dtype: object
# StudentID    S_0_1_1_26
# Score         50.184043
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 116, dtype: object
# StudentID    S_0_1_1_27
# Score         44.738486
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 117, dtype: object
# StudentID    S_0_1_1_28
# Score         72.066495
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 118, dtype: object
# StudentID    S_0_1_1_29
# Score         63.355623
# ClassID         C_0_1_1
# TeacherID         T_0_1
# SchoolID       School_0
# Name: 119, dtype: object
# StudentID    S_0_2_0_0
# Score        72.114288
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 120, dtype: object
# StudentID    S_0_2_0_1
# Score        66.092976
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 121, dtype: object
# StudentID    S_0_2_0_2
# Score        71.474005
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 122, dtype: object
# StudentID    S_0_2_0_3
# Score        56.395443
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 123, dtype: object
# StudentID    S_0_2_0_4
# Score        52.563271
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 124, dtype: object
# StudentID    S_0_2_0_5
# Score        69.721645
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 125, dtype: object
# StudentID    S_0_2_0_6
# Score        54.871603
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 126, dtype: object
# StudentID    S_0_2_0_7
# Score        56.010202
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 127, dtype: object
# StudentID    S_0_2_0_8
# Score        58.350374
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 128, dtype: object
# StudentID    S_0_2_0_9
# Score        63.080491
# ClassID        C_0_2_0
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 129, dtype: object
# StudentID    S_0_2_0_10
# Score          59.36576
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 130, dtype: object
# StudentID    S_0_2_0_11
# Score         49.156186
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 131, dtype: object
# StudentID    S_0_2_0_12
# Score         56.469515
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 132, dtype: object
# StudentID    S_0_2_0_13
# Score         40.671668
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 133, dtype: object
# StudentID    S_0_2_0_14
# Score         69.158014
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 134, dtype: object
# StudentID    S_0_2_0_15
# Score         46.885123
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 135, dtype: object
# StudentID    S_0_2_0_16
# Score         51.861866
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 136, dtype: object
# StudentID    S_0_2_0_17
# Score          63.42735
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 137, dtype: object
# StudentID    S_0_2_0_18
# Score         55.510069
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 138, dtype: object
# StudentID    S_0_2_0_19
# Score         78.335845
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 139, dtype: object
# StudentID    S_0_2_0_20
# Score          49.97713
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 140, dtype: object
# StudentID    S_0_2_0_21
# Score         65.576208
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 141, dtype: object
# StudentID    S_0_2_0_22
# Score         62.512871
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 142, dtype: object
# StudentID    S_0_2_0_23
# Score         51.224764
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 143, dtype: object
# StudentID    S_0_2_0_24
# Score         68.138466
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 144, dtype: object
# StudentID    S_0_2_0_25
# Score         61.190236
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 145, dtype: object
# StudentID    S_0_2_0_26
# Score         70.623605
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 146, dtype: object
# StudentID    S_0_2_0_27
# Score         71.140741
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 147, dtype: object
# StudentID    S_0_2_0_28
# Score         84.538059
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 148, dtype: object
# StudentID    S_0_2_0_29
# Score         76.270979
# ClassID         C_0_2_0
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 149, dtype: object
# StudentID    S_0_2_1_0
# Score         51.76564
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 150, dtype: object
# StudentID    S_0_2_1_1
# Score        53.063667
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 151, dtype: object
# StudentID    S_0_2_1_2
# Score        66.454055
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 152, dtype: object
# StudentID    S_0_2_1_3
# Score        62.010096
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 153, dtype: object
# StudentID    S_0_2_1_4
# Score        61.858774
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 154, dtype: object
# StudentID    S_0_2_1_5
# Score        39.287898
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 155, dtype: object
# StudentID    S_0_2_1_6
# Score        55.214198
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 156, dtype: object
# StudentID    S_0_2_1_7
# Score         48.07715
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 157, dtype: object
# StudentID    S_0_2_1_8
# Score        58.256705
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 158, dtype: object
# StudentID    S_0_2_1_9
# Score        54.475955
# ClassID        C_0_2_1
# TeacherID        T_0_2
# SchoolID      School_0
# Name: 159, dtype: object
# StudentID    S_0_2_1_10
# Score         64.559248
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 160, dtype: object
# StudentID    S_0_2_1_11
# Score         58.629641
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 161, dtype: object
# StudentID    S_0_2_1_12
# Score         63.320738
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 162, dtype: object
# StudentID    S_0_2_1_13
# Score         50.793268
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 163, dtype: object
# StudentID    S_0_2_1_14
# Score         46.012996
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 164, dtype: object
# StudentID    S_0_2_1_15
# Score         51.356962
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 165, dtype: object
# StudentID    S_0_2_1_16
# Score         55.287255
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 166, dtype: object
# StudentID    S_0_2_1_17
# Score         59.248976
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 167, dtype: object
# StudentID    S_0_2_1_18
# Score         78.050548
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 168, dtype: object
# StudentID    S_0_2_1_19
# Score         55.034887
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 169, dtype: object
# StudentID    S_0_2_1_20
# Score         45.898009
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 170, dtype: object
# StudentID    S_0_2_1_21
# Score         51.997641
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 171, dtype: object
# StudentID    S_0_2_1_22
# Score         50.821499
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 172, dtype: object
# StudentID    S_0_2_1_23
# Score         60.272273
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 173, dtype: object
# StudentID    S_0_2_1_24
# Score         40.049489
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 174, dtype: object
# StudentID    S_0_2_1_25
# Score         56.090079
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 175, dtype: object
# StudentID    S_0_2_1_26
# Score         57.022524
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 176, dtype: object
# StudentID    S_0_2_1_27
# Score         57.779269
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 177, dtype: object
# StudentID    S_0_2_1_28
# Score         49.484298
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 178, dtype: object
# StudentID    S_0_2_1_29
# Score         53.078241
# ClassID         C_0_2_1
# TeacherID         T_0_2
# SchoolID       School_0
# Name: 179, dtype: object
# StudentID    S_1_0_0_0
# Score        37.542037
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 180, dtype: object
# StudentID    S_1_0_0_1
# Score        46.849448
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 181, dtype: object
# StudentID    S_1_0_0_2
# Score        46.354032
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 182, dtype: object
# StudentID    S_1_0_0_3
# Score        55.943147
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 183, dtype: object
# StudentID    S_1_0_0_4
# Score        40.220822
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 184, dtype: object
# StudentID    S_1_0_0_5
# Score        59.594628
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 185, dtype: object
# StudentID    S_1_0_0_6
# Score        66.727492
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 186, dtype: object
# StudentID    S_1_0_0_7
# Score        31.082796
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 187, dtype: object
# StudentID    S_1_0_0_8
# Score        56.045234
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 188, dtype: object
# StudentID    S_1_0_0_9
# Score        58.551727
# ClassID        C_1_0_0
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 189, dtype: object
# StudentID    S_1_0_0_10
# Score         45.408276
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 190, dtype: object
# StudentID    S_1_0_0_11
# Score         47.809928
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 191, dtype: object
# StudentID    S_1_0_0_12
# Score         50.453841
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 192, dtype: object
# StudentID    S_1_0_0_13
# Score         48.804738
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 193, dtype: object
# StudentID    S_1_0_0_14
# Score         48.692517
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 194, dtype: object
# StudentID    S_1_0_0_15
# Score         35.022608
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 195, dtype: object
# StudentID    S_1_0_0_16
# Score         63.305962
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 196, dtype: object
# StudentID    S_1_0_0_17
# Score         62.578832
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 197, dtype: object
# StudentID    S_1_0_0_18
# Score         43.649004
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 198, dtype: object
# StudentID    S_1_0_0_19
# Score         37.118403
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 199, dtype: object
# StudentID    S_1_0_0_20
# Score         56.993295
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 200, dtype: object
# StudentID    S_1_0_0_21
# Score         46.024767
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 201, dtype: object
# StudentID    S_1_0_0_22
# Score         53.202178
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 202, dtype: object
# StudentID    S_1_0_0_23
# Score         48.589362
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 203, dtype: object
# StudentID    S_1_0_0_24
# Score         58.698034
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 204, dtype: object
# StudentID    S_1_0_0_25
# Score         58.730138
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 205, dtype: object
# StudentID    S_1_0_0_26
# Score         44.526673
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 206, dtype: object
# StudentID    S_1_0_0_27
# Score         37.949007
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 207, dtype: object
# StudentID    S_1_0_0_28
# Score         35.953263
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 208, dtype: object
# StudentID    S_1_0_0_29
# Score          57.88644
# ClassID         C_1_0_0
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 209, dtype: object
# StudentID    S_1_0_1_0
# Score        39.428169
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 210, dtype: object
# StudentID    S_1_0_1_1
# Score        46.248598
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 211, dtype: object
# StudentID    S_1_0_1_2
# Score        45.353621
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 212, dtype: object
# StudentID    S_1_0_1_3
# Score        50.791089
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 213, dtype: object
# StudentID    S_1_0_1_4
# Score        31.953964
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 214, dtype: object
# StudentID    S_1_0_1_5
# Score        53.204548
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 215, dtype: object
# StudentID    S_1_0_1_6
# Score        56.555672
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 216, dtype: object
# StudentID    S_1_0_1_7
# Score        52.200983
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 217, dtype: object
# StudentID    S_1_0_1_8
# Score          48.2079
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 218, dtype: object
# StudentID    S_1_0_1_9
# Score        52.290763
# ClassID        C_1_0_1
# TeacherID        T_1_0
# SchoolID      School_1
# Name: 219, dtype: object
# StudentID    S_1_0_1_10
# Score         55.307225
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 220, dtype: object
# StudentID    S_1_0_1_11
# Score         23.590834
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 221, dtype: object
# StudentID    S_1_0_1_12
# Score         70.875885
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 222, dtype: object
# StudentID    S_1_0_1_13
# Score         55.217695
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 223, dtype: object
# StudentID    S_1_0_1_14
# Score         44.792676
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 224, dtype: object
# StudentID    S_1_0_1_15
# Score         47.407228
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 225, dtype: object
# StudentID    S_1_0_1_16
# Score          56.25418
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 226, dtype: object
# StudentID    S_1_0_1_17
# Score         50.155722
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 227, dtype: object
# StudentID    S_1_0_1_18
# Score         31.009917
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 228, dtype: object
# StudentID    S_1_0_1_19
# Score          71.96169
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 229, dtype: object
# StudentID    S_1_0_1_20
# Score         50.211355
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 230, dtype: object
# StudentID    S_1_0_1_21
# Score         61.518489
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 231, dtype: object
# StudentID    S_1_0_1_22
# Score         44.396263
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 232, dtype: object
# StudentID    S_1_0_1_23
# Score         66.680532
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 233, dtype: object
# StudentID    S_1_0_1_24
# Score         54.180199
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 234, dtype: object
# StudentID    S_1_0_1_25
# Score           57.4052
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 235, dtype: object
# StudentID    S_1_0_1_26
# Score         40.864228
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 236, dtype: object
# StudentID    S_1_0_1_27
# Score         63.428215
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 237, dtype: object
# StudentID    S_1_0_1_28
# Score         58.214943
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 238, dtype: object
# StudentID    S_1_0_1_29
# Score         64.335224
# ClassID         C_1_0_1
# TeacherID         T_1_0
# SchoolID       School_1
# Name: 239, dtype: object
# StudentID    S_1_1_0_0
# Score        50.017264
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 240, dtype: object
# StudentID    S_1_1_0_1
# Score        51.487869
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 241, dtype: object
# StudentID    S_1_1_0_2
# Score        79.337307
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 242, dtype: object
# StudentID    S_1_1_0_3
# Score        45.697982
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 243, dtype: object
# StudentID    S_1_1_0_4
# Score        54.938643
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 244, dtype: object
# StudentID    S_1_1_0_5
# Score        67.667054
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 245, dtype: object
# StudentID    S_1_1_0_6
# Score         57.27539
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 246, dtype: object
# StudentID    S_1_1_0_7
# Score        62.127677
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 247, dtype: object
# StudentID    S_1_1_0_8
# Score         52.30365
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 248, dtype: object
# StudentID    S_1_1_0_9
# Score        59.998699
# ClassID        C_1_1_0
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 249, dtype: object
# StudentID    S_1_1_0_10
# Score         43.232871
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 250, dtype: object
# StudentID    S_1_1_0_11
# Score         72.879447
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 251, dtype: object
# StudentID    S_1_1_0_12
# Score           55.1165
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 252, dtype: object
# StudentID    S_1_1_0_13
# Score         49.496358
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 253, dtype: object
# StudentID    S_1_1_0_14
# Score         62.961971
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 254, dtype: object
# StudentID    S_1_1_0_15
# Score         51.690942
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 255, dtype: object
# StudentID    S_1_1_0_16
# Score         42.955555
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 256, dtype: object
# StudentID    S_1_1_0_17
# Score         42.830965
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 257, dtype: object
# StudentID    S_1_1_0_18
# Score         63.235872
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 258, dtype: object
# StudentID    S_1_1_0_19
# Score         54.702406
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 259, dtype: object
# StudentID    S_1_1_0_20
# Score         54.961124
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 260, dtype: object
# StudentID    S_1_1_0_21
# Score         67.075578
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 261, dtype: object
# StudentID    S_1_1_0_22
# Score         45.029882
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 262, dtype: object
# StudentID    S_1_1_0_23
# Score         48.991362
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 263, dtype: object
# StudentID    S_1_1_0_24
# Score         52.449342
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 264, dtype: object
# StudentID    S_1_1_0_25
# Score         57.241656
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 265, dtype: object
# StudentID    S_1_1_0_26
# Score         55.876425
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 266, dtype: object
# StudentID    S_1_1_0_27
# Score         53.429268
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 267, dtype: object
# StudentID    S_1_1_0_28
# Score         55.681876
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 268, dtype: object
# StudentID    S_1_1_0_29
# Score         55.225087
# ClassID         C_1_1_0
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 269, dtype: object
# StudentID    S_1_1_1_0
# Score        48.975255
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 270, dtype: object
# StudentID    S_1_1_1_1
# Score        48.041369
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 271, dtype: object
# StudentID    S_1_1_1_2
# Score        58.916463
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 272, dtype: object
# StudentID    S_1_1_1_3
# Score        47.262148
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 273, dtype: object
# StudentID    S_1_1_1_4
# Score        44.597746
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 274, dtype: object
# StudentID    S_1_1_1_5
# Score        53.048377
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 275, dtype: object
# StudentID    S_1_1_1_6
# Score        54.594629
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 276, dtype: object
# StudentID    S_1_1_1_7
# Score        78.738534
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 277, dtype: object
# StudentID    S_1_1_1_8
# Score        49.124296
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 278, dtype: object
# StudentID    S_1_1_1_9
# Score        65.603906
# ClassID        C_1_1_1
# TeacherID        T_1_1
# SchoolID      School_1
# Name: 279, dtype: object
# StudentID    S_1_1_1_10
# Score         63.643182
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 280, dtype: object
# StudentID    S_1_1_1_11
# Score          44.28185
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 281, dtype: object
# StudentID    S_1_1_1_12
# Score         63.903829
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 282, dtype: object
# StudentID    S_1_1_1_13
# Score         44.332493
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 283, dtype: object
# StudentID    S_1_1_1_14
# Score         29.579577
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 284, dtype: object
# StudentID    S_1_1_1_15
# Score         62.234494
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 285, dtype: object
# StudentID    S_1_1_1_16
# Score         38.612393
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 286, dtype: object
# StudentID    S_1_1_1_17
# Score         60.680644
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 287, dtype: object
# StudentID    S_1_1_1_18
# Score          49.33119
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 288, dtype: object
# StudentID    S_1_1_1_19
# Score         72.766807
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 289, dtype: object
# StudentID    S_1_1_1_20
# Score         66.856393
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 290, dtype: object
# StudentID    S_1_1_1_21
# Score         51.637441
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 291, dtype: object
# StudentID    S_1_1_1_22
# Score         49.292923
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 292, dtype: object
# StudentID    S_1_1_1_23
# Score         44.030525
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 293, dtype: object
# StudentID    S_1_1_1_24
# Score         51.762073
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 294, dtype: object
# StudentID    S_1_1_1_25
# Score         53.367744
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 295, dtype: object
# StudentID    S_1_1_1_26
# Score         52.524364
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 296, dtype: object
# StudentID    S_1_1_1_27
# Score         57.738338
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 297, dtype: object
# StudentID    S_1_1_1_28
# Score         61.956514
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 298, dtype: object
# StudentID    S_1_1_1_29
# Score         59.667844
# ClassID         C_1_1_1
# TeacherID         T_1_1
# SchoolID       School_1
# Name: 299, dtype: object
# StudentID    S_1_2_0_0
# Score        45.101372
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 300, dtype: object
# StudentID    S_1_2_0_1
# Score        38.364897
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 301, dtype: object
# StudentID    S_1_2_0_2
# Score         66.38813
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 302, dtype: object
# StudentID    S_1_2_0_3
# Score         45.84832
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 303, dtype: object
# StudentID    S_1_2_0_4
# Score        46.219876
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 304, dtype: object
# StudentID    S_1_2_0_5
# Score        47.530918
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 305, dtype: object
# StudentID    S_1_2_0_6
# Score        34.312116
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 306, dtype: object
# StudentID    S_1_2_0_7
# Score        47.963072
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 307, dtype: object
# StudentID    S_1_2_0_8
# Score        47.946253
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 308, dtype: object
# StudentID    S_1_2_0_9
# Score        58.946395
# ClassID        C_1_2_0
# TeacherID        T_1_2
# SchoolID      School_1
# Name: 309, dtype: object
# StudentID    S_1_2_0_10
# Score         59.727383
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 310, dtype: object
# StudentID    S_1_2_0_11
# Score          52.78052
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 311, dtype: object
# StudentID    S_1_2_0_12
# Score         62.061295
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 312, dtype: object
# StudentID    S_1_2_0_13
# Score         56.142461
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 313, dtype: object
# StudentID    S_1_2_0_14
# Score          52.58599
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 314, dtype: object
# StudentID    S_1_2_0_15
# Score         54.352093
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 315, dtype: object
# StudentID    S_1_2_0_16
# Score         50.836277
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 316, dtype: object
# StudentID    S_1_2_0_17
# Score         48.794316
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 317, dtype: object
# StudentID    S_1_2_0_18
# Score         50.065476
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 318, dtype: object
# StudentID    S_1_2_0_19
# Score         41.462698
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 319, dtype: object
# StudentID    S_1_2_0_20
# Score         55.547229
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 320, dtype: object
# StudentID    S_1_2_0_21
# Score         42.811575
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 321, dtype: object
# StudentID    S_1_2_0_22
# Score         61.159124
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 322, dtype: object
# StudentID    S_1_2_0_23
# Score         50.248226
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 323, dtype: object
# StudentID    S_1_2_0_24
# Score         53.237761
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 324, dtype: object
# StudentID    S_1_2_0_25
# Score         57.681179
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 325, dtype: object
# StudentID    S_1_2_0_26
# Score         59.175956
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 326, dtype: object
# StudentID    S_1_2_0_27
# Score         37.036578
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 327, dtype: object
# StudentID    S_1_2_0_28
# Score         50.673775
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 328, dtype: object
# StudentID    S_1_2_0_29
# Score         61.544601
# ClassID         C_1_2_0
# TeacherID         T_1_2
# SchoolID       School_1
# Name: 329, dtype: object
# StudentID    S_1_2_1_0
# Score        36.208184
# ...
# SchoolID      School_4
# Name: 788, dtype: object
# StudentID    S_4_1_0_9
# Score        60.885873
# ClassID        C_4_1_0
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 789, dtype: object
# StudentID    S_4_1_0_10
# Score          60.16723
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 790, dtype: object
# StudentID    S_4_1_0_11
# Score         54.073391
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 791, dtype: object
# StudentID    S_4_1_0_12
# Score          67.49676
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 792, dtype: object
# StudentID    S_4_1_0_13
# Score         79.110085
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 793, dtype: object
# StudentID    S_4_1_0_14
# Score         61.835557
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 794, dtype: object
# StudentID    S_4_1_0_15
# Score         55.839635
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 795, dtype: object
# StudentID    S_4_1_0_16
# Score         65.328805
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 796, dtype: object
# StudentID    S_4_1_0_17
# Score         52.380076
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 797, dtype: object
# StudentID    S_4_1_0_18
# Score         50.274499
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 798, dtype: object
# StudentID    S_4_1_0_19
# Score          58.09949
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 799, dtype: object
# StudentID    S_4_1_0_20
# Score         31.943436
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 800, dtype: object
# StudentID    S_4_1_0_21
# Score         46.231899
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 801, dtype: object
# StudentID    S_4_1_0_22
# Score         54.291784
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 802, dtype: object
# StudentID    S_4_1_0_23
# Score         44.237514
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 803, dtype: object
# StudentID    S_4_1_0_24
# Score         47.444971
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 804, dtype: object
# StudentID    S_4_1_0_25
# Score         53.403919
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 805, dtype: object
# StudentID    S_4_1_0_26
# Score         41.341749
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 806, dtype: object
# StudentID    S_4_1_0_27
# Score         53.710684
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 807, dtype: object
# StudentID    S_4_1_0_28
# Score         52.418701
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 808, dtype: object
# StudentID    S_4_1_0_29
# Score         58.025454
# ClassID         C_4_1_0
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 809, dtype: object
# StudentID    S_4_1_1_0
# Score        73.373814
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 810, dtype: object
# StudentID    S_4_1_1_1
# Score        63.557018
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 811, dtype: object
# StudentID    S_4_1_1_2
# Score        62.042594
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 812, dtype: object
# StudentID    S_4_1_1_3
# Score        62.826518
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 813, dtype: object
# StudentID    S_4_1_1_4
# Score        64.105902
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 814, dtype: object
# StudentID    S_4_1_1_5
# Score        51.664587
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 815, dtype: object
# StudentID    S_4_1_1_6
# Score        60.684221
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 816, dtype: object
# StudentID    S_4_1_1_7
# Score        64.919486
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 817, dtype: object
# StudentID    S_4_1_1_8
# Score        48.124374
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 818, dtype: object
# StudentID    S_4_1_1_9
# Score        70.488503
# ClassID        C_4_1_1
# TeacherID        T_4_1
# SchoolID      School_4
# Name: 819, dtype: object
# StudentID    S_4_1_1_10
# Score         72.645734
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 820, dtype: object
# StudentID    S_4_1_1_11
# Score         55.518214
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 821, dtype: object
# StudentID    S_4_1_1_12
# Score         59.418596
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 822, dtype: object
# StudentID    S_4_1_1_13
# Score          53.05007
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 823, dtype: object
# StudentID    S_4_1_1_14
# Score         68.825779
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 824, dtype: object
# StudentID    S_4_1_1_15
# Score         51.219751
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 825, dtype: object
# StudentID    S_4_1_1_16
# Score         59.607204
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 826, dtype: object
# StudentID    S_4_1_1_17
# Score         53.242775
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 827, dtype: object
# StudentID    S_4_1_1_18
# Score         62.341517
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 828, dtype: object
# StudentID    S_4_1_1_19
# Score         43.889681
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 829, dtype: object
# StudentID    S_4_1_1_20
# Score          75.09659
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 830, dtype: object
# StudentID    S_4_1_1_21
# Score          52.18591
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 831, dtype: object
# StudentID    S_4_1_1_22
# Score         62.430921
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 832, dtype: object
# StudentID    S_4_1_1_23
# Score         59.706743
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 833, dtype: object
# StudentID    S_4_1_1_24
# Score         54.210829
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 834, dtype: object
# StudentID    S_4_1_1_25
# Score         52.954172
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 835, dtype: object
# StudentID    S_4_1_1_26
# Score         71.195959
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 836, dtype: object
# StudentID    S_4_1_1_27
# Score         56.575568
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 837, dtype: object
# StudentID    S_4_1_1_28
# Score         64.543676
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 838, dtype: object
# StudentID    S_4_1_1_29
# Score         53.817005
# ClassID         C_4_1_1
# TeacherID         T_4_1
# SchoolID       School_4
# Name: 839, dtype: object
# StudentID    S_4_2_0_0
# Score        47.075893
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 840, dtype: object
# StudentID    S_4_2_0_1
# Score        58.270179
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 841, dtype: object
# StudentID    S_4_2_0_2
# Score        62.851792
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 842, dtype: object
# StudentID    S_4_2_0_3
# Score        51.794543
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 843, dtype: object
# StudentID    S_4_2_0_4
# Score        39.328508
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 844, dtype: object
# StudentID    S_4_2_0_5
# Score        73.527268
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 845, dtype: object
# StudentID    S_4_2_0_6
# Score        44.982214
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 846, dtype: object
# StudentID    S_4_2_0_7
# Score        38.131833
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 847, dtype: object
# StudentID    S_4_2_0_8
# Score        79.491953
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 848, dtype: object
# StudentID    S_4_2_0_9
# Score        49.507384
# ClassID        C_4_2_0
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 849, dtype: object
# StudentID    S_4_2_0_10
# Score          38.93038
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 850, dtype: object
# StudentID    S_4_2_0_11
# Score         46.713309
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 851, dtype: object
# StudentID    S_4_2_0_12
# Score         57.223156
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 852, dtype: object
# StudentID    S_4_2_0_13
# Score         55.450823
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 853, dtype: object
# StudentID    S_4_2_0_14
# Score         45.030415
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 854, dtype: object
# StudentID    S_4_2_0_15
# Score         71.774943
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 855, dtype: object
# StudentID    S_4_2_0_16
# Score          48.33191
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 856, dtype: object
# StudentID    S_4_2_0_17
# Score         41.700841
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 857, dtype: object
# StudentID    S_4_2_0_18
# Score         63.154641
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 858, dtype: object
# StudentID    S_4_2_0_19
# Score         66.838336
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 859, dtype: object
# StudentID    S_4_2_0_20
# Score         45.372776
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 860, dtype: object
# StudentID    S_4_2_0_21
# Score         39.534234
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 861, dtype: object
# StudentID    S_4_2_0_22
# Score          63.85209
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 862, dtype: object
# StudentID    S_4_2_0_23
# Score         33.074471
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 863, dtype: object
# StudentID    S_4_2_0_24
# Score          41.28149
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 864, dtype: object
# StudentID    S_4_2_0_25
# Score         63.222169
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 865, dtype: object
# StudentID    S_4_2_0_26
# Score         52.994182
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 866, dtype: object
# StudentID    S_4_2_0_27
# Score         50.908334
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 867, dtype: object
# StudentID    S_4_2_0_28
# Score         57.075873
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 868, dtype: object
# StudentID    S_4_2_0_29
# Score         52.019963
# ClassID         C_4_2_0
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 869, dtype: object
# StudentID    S_4_2_1_0
# Score        43.363155
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 870, dtype: object
# StudentID    S_4_2_1_1
# Score        69.110776
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 871, dtype: object
# StudentID    S_4_2_1_2
# Score        69.600163
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 872, dtype: object
# StudentID    S_4_2_1_3
# Score        58.403348
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 873, dtype: object
# StudentID    S_4_2_1_4
# Score        56.801362
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 874, dtype: object
# StudentID    S_4_2_1_5
# Score         79.74627
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 875, dtype: object
# StudentID    S_4_2_1_6
# Score        53.585694
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 876, dtype: object
# StudentID    S_4_2_1_7
# Score        53.754252
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 877, dtype: object
# StudentID    S_4_2_1_8
# Score        59.994835
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 878, dtype: object
# StudentID    S_4_2_1_9
# Score        71.063242
# ClassID        C_4_2_1
# TeacherID        T_4_2
# SchoolID      School_4
# Name: 879, dtype: object
# StudentID    S_4_2_1_10
# Score          72.27773
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 880, dtype: object
# StudentID    S_4_2_1_11
# Score         53.764296
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 881, dtype: object
# StudentID    S_4_2_1_12
# Score         59.433335
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 882, dtype: object
# StudentID    S_4_2_1_13
# Score         42.569188
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 883, dtype: object
# StudentID    S_4_2_1_14
# Score         53.230261
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 884, dtype: object
# StudentID    S_4_2_1_15
# Score         47.947118
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 885, dtype: object
# StudentID    S_4_2_1_16
# Score         46.281705
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 886, dtype: object
# StudentID    S_4_2_1_17
# Score         73.165789
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 887, dtype: object
# StudentID    S_4_2_1_18
# Score         48.427156
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 888, dtype: object
# StudentID    S_4_2_1_19
# Score         51.033963
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 889, dtype: object
# StudentID    S_4_2_1_20
# Score          60.00851
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 890, dtype: object
# StudentID    S_4_2_1_21
# Score         69.328275
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 891, dtype: object
# StudentID    S_4_2_1_22
# Score         61.161173
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 892, dtype: object
# StudentID    S_4_2_1_23
# Score         83.943573
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 893, dtype: object
# StudentID    S_4_2_1_24
# Score         55.603342
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 894, dtype: object
# StudentID    S_4_2_1_25
# Score         58.937187
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 895, dtype: object
# StudentID    S_4_2_1_26
# Score         59.106029
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 896, dtype: object
# StudentID    S_4_2_1_27
# Score         70.700516
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 897, dtype: object
# StudentID    S_4_2_1_28
# Score         61.422412
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 898, dtype: object
# StudentID    S_4_2_1_29
# Score         55.187725
# ClassID         C_4_2_1
# TeacherID         T_4_2
# SchoolID       School_4
# Name: 899, dtype: object

# %%
n_classes=df['ClassID'].nunique()
n_teachers=df['TeacherID'].nunique()
n_schools=df['SchoolID'].nunique()
n_students=df['StudentID'].nunique()

# %%
# モデルの定義

# データセットの設定
# n_schools = 5  # 学校の数
# n_teachers_per_school = 3  # 各学校における教師の数
# n_classes_per_teacher = 2  # 各教師におけるクラスの数
# n_students_per_class = 30  # 各クラスにおける学生の数


# 入力データとしてクラスごとの平均を取るべきか
class BeyesModel(pm.Model):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        with self:
            self.add_coord(name="school", values=[f"School_{i}" for i in range(n_schools)])
            self.add_coord(name="teacher", values=[f"T_{i}_{j}" for j in range(n_teachers) for i in range(n_schools)])
            self.add_coord(name="class", values=[f"C_{i}_{j}_{k}" for k in range(n_classes) for j in range(n_teachers) for i in range(n_schools)])
            
            school_mean = pm.Normal(name='school_mean', mu=50, sigma=10, dims="school")
            teacher_mean = pm.Normal(name='teacher_mean', mu=0, sigma=10)
            class_sigma = pm.HalfCauchy(name='class_sigma', beta=5, dims="class")
            
            pm.Normal(name='class_score', mu=school_mean[int(df["SchoolID"][-1])] + teacher_mean[int(df["SchoolID"][-1])*n_teachers_per_school+int(data["TeacherID"][-3])], sigma=class_sigma, dims="class")
            
            
model = BeyesModel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Development/analysis-environment/.venv/lib/python3.11/site-packages/pandas/core/indexes/range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 24
#      19             class_sigma = pm.HalfCauchy(name='class_sigma', beta=5, dims="class")
#      21             pm.Normal(name='class_score', mu=school_mean[int(df["SchoolID"][-1])] + teacher_mean[int(df["SchoolID"][-1])*n_teachers_per_school+int(data["TeacherID"][-3])], sigma=class_sigma, dims="class")
# ---> 24 model = BeyesModel()
#
# File ~/Development/analysis-environment/.venv/lib/python3.11/site-packages/pymc/model/core.py:223, in ContextMeta.__call__(cls, *args, **kwargs)
#     221 instance: "Model" = cls.__new__(cls, *args, **kwargs)
#     222 with instance:  # appends context
# --> 223     instance.__init__(*args, **kwargs)
#     224 return instance
#
# Cell In[40], line 21, in BeyesModel.__init__(self, *args, **kwargs)
#      18 teacher_mean = pm.Normal(name='teacher_mean', mu=0, sigma=10)
#      19 class_sigma = pm.HalfCauchy(name='class_sigma', beta=5, dims="class")
# ---> 21 pm.Normal(name='class_score', mu=school_mean[int(df["SchoolID"][-1])] + teacher_mean[int(df["SchoolID"][-1])*n_teachers_per_school+int(data["TeacherID"][-3])], sigma=class_sigma, dims="class")
#
# File ~/Development/analysis-environment/.venv/lib/python3.11/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~/Development/analysis-environment/.venv/lib/python3.11/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~/Development/analysis-environment/.venv/lib/python3.11/site-packages/pandas/core/indexes/range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: -1
